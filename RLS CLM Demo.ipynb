# %% [markdown]
# # Row Filtering and Column Masking

# %%
# %sql
drop schema if exists dkushari_uc.fgac cascade;
create schema if not exists dkushari_uc.fgac managed location "abfss://dkushari@dkusharistorageaccount.dfs.core.windows.net/mars/rlsclm/";

# %%
# %sql
use catalog dkushari_uc;
use fgac;

# %%
# %sql
select current_catalog();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th></tr></thead><tbody><tr><td>dkushari_uc</td></tr></tbody></table></div>

# %%
# %sql
select current_schema();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_schema()</th></tr></thead><tbody><tr><td>fgac</td></tr></tbody></table></div>

# %%
# %sql 
DROP TABLE IF EXISTS customer_pii_data_parquet;
DROP TABLE IF EXISTS customer_pii_data_delta;

# %%
from pyspark.sql.functions import expr, lit, rand
from pyspark.sql.types import IntegerType

# Generate a DataFrame with 50 records
df = spark.range(50).withColumnRenamed("id", "record_id")

# Add PII information (dummy data for illustration)
df = df.withColumn("first_name", expr("CASE WHEN rand() < 0.2 THEN 'John' " +
                                      "WHEN rand() < 0.4 THEN 'Jane' " +
                                      "WHEN rand() < 0.6 THEN 'Doe' " +
                                      "WHEN rand() < 0.8 THEN 'Alice' " +
                                      "ELSE 'Bob' END")) \
      .withColumn("last_name", expr("CASE WHEN rand() < 0.2 THEN 'Smith' " +
                                    "WHEN rand() < 0.4 THEN 'Johnson' " +
                                    "WHEN rand() < 0.6 THEN 'Williams' " +
                                    "WHEN rand() < 0.8 THEN 'Brown' " +
                                    "ELSE 'Jones' END")) \
      .withColumn("date_of_birth", expr("CASE WHEN rand() < 0.2 THEN '1980-01-01' " +
                                        "WHEN rand() < 0.4 THEN '1990-01-01' " +
                                        "WHEN rand() < 0.6 THEN '2000-01-01' " +
                                        "WHEN rand() < 0.8 THEN '1985-01-01' " +
                                        "ELSE '1995-01-01' END")) \
      .withColumn("age", (lit(2023) - expr("substring(date_of_birth, 1, 4)")).cast(IntegerType())) \
      .withColumn("gender", expr("CASE WHEN rand() < 0.5 THEN 'M' ELSE 'F' END")) \
      .withColumn("address", expr("CASE WHEN rand() < 0.2 THEN '123 Main St' " +
                                  "WHEN rand() < 0.4 THEN '456 Elm St' " +
                                  "WHEN rand() < 0.6 THEN '789 Pine St' " +
                                  "WHEN rand() < 0.8 THEN '101 Oak St' " +
                                  "ELSE '202 Maple St' END")) \
      .withColumn("ssn", expr("CASE WHEN rand() < 0.2 THEN '111-11-1111' " +
                              "WHEN rand() < 0.4 THEN '222-22-2222' " +
                              "WHEN rand() < 0.6 THEN '333-33-3333' " +
                              "WHEN rand() < 0.8 THEN '444-44-4444' " +
                              "ELSE '555-55-5555' END")) \
      .withColumn("region", expr("CASE WHEN rand() < 0.2 THEN 'Northeast' " +
                                 "WHEN rand() < 0.4 THEN 'Midwest' " +
                                 "WHEN rand() < 0.6 THEN 'South' " +
                                 "WHEN rand() < 0.8 THEN 'West' " +
                                 "ELSE 'Southwest' END"))

# Display the DataFrame
# display(df)

# Write the DataFrame to a Unity Catalog table
df.write.format("parquet").mode("overwrite").option("path","abfss://dkushari@dkusharistorageaccount.dfs.core.windows.net/mars/rlsclm/external-table").saveAsTable("customer_pii_data_parquet")

# %%
# %sql
select * from dkushari_uc.fgac.customer_pii_data_parquet limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>record_id</th><th>first_name</th><th>last_name</th><th>date_of_birth</th><th>age</th><th>gender</th><th>address</th><th>ssn</th><th>region</th></tr></thead><tbody><tr><td>18</td><td>Doe</td><td>Williams</td><td>2000-01-01</td><td>23</td><td>F</td><td>123 Main St</td><td>111-11-1111</td><td>West</td></tr><tr><td>19</td><td>John</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>M</td><td>456 Elm St</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>20</td><td>John</td><td>Williams</td><td>1990-01-01</td><td>33</td><td>F</td><td>789 Pine St</td><td>333-33-3333</td><td>Southwest</td></tr><tr><td>37</td><td>John</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>M</td><td>789 Pine St</td><td>333-33-3333</td><td>Midwest</td></tr><tr><td>38</td><td>John</td><td>Smith</td><td>2000-01-01</td><td>23</td><td>M</td><td>789 Pine St</td><td>111-11-1111</td><td>Northeast</td></tr><tr><td>39</td><td>John</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>F</td><td>789 Pine St</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>34</td><td>Jane</td><td>Brown</td><td>1995-01-01</td><td>28</td><td>F</td><td>123 Main St</td><td>222-22-2222</td><td>South</td></tr><tr><td>35</td><td>Jane</td><td>Brown</td><td>1990-01-01</td><td>33</td><td>M</td><td>789 Pine St</td><td>555-55-5555</td><td>Northeast</td></tr><tr><td>36</td><td>Doe</td><td>Brown</td><td>1985-01-01</td><td>38</td><td>F</td><td>456 Elm St</td><td>333-33-3333</td><td>Northeast</td></tr><tr><td>9</td><td>Jane</td><td>Johnson</td><td>1980-01-01</td><td>43</td><td>F</td><td>456 Elm St</td><td>555-55-5555</td><td>South</td></tr></tbody></table></div>

# %%
# %sql
insert into dkushari_uc.fgac.customer_pii_data_parquet
select * from dkushari_uc.fgac.customer_pii_data_parquet limit 100;

# %%
# %sql
insert into dkushari_uc.fgac.customer_pii_data_parquet
select * from dkushari_uc.fgac.customer_pii_data_parquet where first_name = 'Doe' and last_name = 'Williams'

# %%
# %sql
select count(*) from dkushari_uc.fgac.customer_pii_data_parquet;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>106</td></tr></tbody></table></div>

# %%
# %sql
create table if not exists customer_pii_data_delta deep clone customer_pii_data_parquet;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_table_size</th><th>source_num_of_files</th><th>num_of_synced_transactions</th><th>num_removed_files</th><th>num_copied_files</th><th>removed_files_size</th><th>copied_files_size</th></tr></thead><tbody><tr><td>52454</td><td>21</td><td>null</td><td>0</td><td>21</td><td>0</td><td>52454</td></tr></tbody></table></div>

# %% [markdown]
# ## Customer Table with PII data

# %%
# %sql
SELECT region, COUNT(*) AS total_customers
FROM customer_pii_data_parquet
GROUP BY region;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>total_customers</th></tr></thead><tbody><tr><td>Midwest</td><td>30</td></tr><tr><td>South</td><td>32</td></tr><tr><td>Southwest</td><td>4</td></tr><tr><td>West</td><td>20</td></tr><tr><td>Northeast</td><td>20</td></tr></tbody></table></div>

# %%
# %sql
SELECT region, COUNT(*) AS total_customers
FROM customer_pii_data_delta
GROUP BY region;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>total_customers</th></tr></thead><tbody><tr><td>Midwest</td><td>30</td></tr><tr><td>South</td><td>32</td></tr><tr><td>Southwest</td><td>4</td></tr><tr><td>West</td><td>20</td></tr><tr><td>Northeast</td><td>20</td></tr></tbody></table></div>

# %% [markdown]
# # Create column masking UC functions

# %%
# %sql
use catalog dkushari_uc;
use fgac;

# %% [markdown]
# ## The Column mask function does the folowing -
#   - If the user is part of the mars_group_2 then they are not restricted to any masking
#   - If the user is part of the mars_group_1 and satisfy certain criteria for another column then column_1 for those rows are not masked
#   - Otherwise the data in column_1 is masked

# %%
# %sql
drop function if exists fn_col_mask;
CREATE OR REPLACE FUNCTION fn_col_mask(column_1 STRING, column_2 STRING, column_value_3 STRING) 
  RETURN IF((is_account_group_member("mars_group_1") AND column_2 = column_value_3) OR 
            (is_account_group_member("mars_group_2")),
            column_1, "❌❌❌❌❌"
  );

# %% [markdown]
# ## Alter table to add column mask - Using Delta table

# %%
# %sql
ALTER TABLE customer_pii_data_delta ALTER COLUMN ssn DROP MASK;

# %% [markdown]
# #### For Gender=M, SSN is masked if the user belongs to mars_group_1

# %%
# %sql
ALTER TABLE customer_pii_data_delta
  ALTER COLUMN ssn SET MASK fn_col_mask using columns (gender,'M');

# %% [markdown]
# ### Test 1 -
#   - User is part of mars_group_2 which is allowed to see all the data as per the function

# %%
# %sql
SELECT is_account_group_member('mars_group_1') as group_1, is_account_group_member('mars_group_2') as group_2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>group_1</th><th>group_2</th></tr></thead><tbody><tr><td>false</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
select * from customer_pii_data_delta order by record_id limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>record_id</th><th>first_name</th><th>last_name</th><th>date_of_birth</th><th>age</th><th>gender</th><th>address</th><th>ssn</th><th>region</th></tr></thead><tbody><tr><td>0</td><td>Doe</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>101 Oak St</td><td>444-44-4444</td><td>South</td></tr><tr><td>0</td><td>Doe</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>101 Oak St</td><td>444-44-4444</td><td>South</td></tr><tr><td>1</td><td>Alice</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>M</td><td>123 Main St</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>1</td><td>Alice</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>M</td><td>123 Main St</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>2</td><td>Doe</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>789 Pine St</td><td>333-33-3333</td><td>Northeast</td></tr><tr><td>2</td><td>Doe</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>789 Pine St</td><td>333-33-3333</td><td>Northeast</td></tr><tr><td>3</td><td>Alice</td><td>Johnson</td><td>1990-01-01</td><td>33</td><td>M</td><td>202 Maple St</td><td>222-22-2222</td><td>Northeast</td></tr><tr><td>3</td><td>Alice</td><td>Johnson</td><td>1990-01-01</td><td>33</td><td>M</td><td>202 Maple St</td><td>222-22-2222</td><td>Northeast</td></tr><tr><td>4</td><td>Jane</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>456 Elm St</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>4</td><td>Jane</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>456 Elm St</td><td>222-22-2222</td><td>Midwest</td></tr></tbody></table></div>

# %% [markdown]
# ### Test 2 -
#   - Group membership changed - User is now part of mars_group_1 which is Not allowed to see all the data as per the function
#   - the association of the function to the table via Alter table only allows to see SSN data when gender is M

# %%
# %sql
SELECT is_account_group_member('mars_group_1') as group_1, is_account_group_member('mars_group_2') as group_2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>group_1</th><th>group_2</th></tr></thead><tbody><tr><td>true</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
select * from customer_pii_data_delta order by record_id limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>record_id</th><th>first_name</th><th>last_name</th><th>date_of_birth</th><th>age</th><th>gender</th><th>address</th><th>ssn</th><th>region</th></tr></thead><tbody><tr><td>0</td><td>Doe</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>101 Oak St</td><td>❌❌❌❌❌</td><td>South</td></tr><tr><td>0</td><td>Doe</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>101 Oak St</td><td>❌❌❌❌❌</td><td>South</td></tr><tr><td>1</td><td>Alice</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>M</td><td>123 Main St</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>1</td><td>Alice</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>M</td><td>123 Main St</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>2</td><td>Doe</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>789 Pine St</td><td>❌❌❌❌❌</td><td>Northeast</td></tr><tr><td>2</td><td>Doe</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>789 Pine St</td><td>❌❌❌❌❌</td><td>Northeast</td></tr><tr><td>3</td><td>Alice</td><td>Johnson</td><td>1990-01-01</td><td>33</td><td>M</td><td>202 Maple St</td><td>222-22-2222</td><td>Northeast</td></tr><tr><td>3</td><td>Alice</td><td>Johnson</td><td>1990-01-01</td><td>33</td><td>M</td><td>202 Maple St</td><td>222-22-2222</td><td>Northeast</td></tr><tr><td>4</td><td>Jane</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>456 Elm St</td><td>❌❌❌❌❌</td><td>Midwest</td></tr><tr><td>4</td><td>Jane</td><td>Johnson</td><td>1985-01-01</td><td>38</td><td>F</td><td>456 Elm St</td><td>❌❌❌❌❌</td><td>Midwest</td></tr></tbody></table></div>

# %% [markdown]
# ## Alter table to add column mask - Using Parquet table

# %%
# %sql
ALTER TABLE customer_pii_data_parquet ALTER COLUMN date_of_birth DROP MASK;
ALTER TABLE customer_pii_data_parquet ALTER COLUMN address DROP MASK;

# %% [markdown]
# #### Irrespective of Gender, DoB is masked if the user belongs to mars_group_1

# %%
# %sql
ALTER TABLE customer_pii_data_parquet
  ALTER COLUMN date_of_birth SET MASK fn_col_mask USING COLUMNS (gender,'') ;

# %% [markdown]
# #### Address is masked for regions other than West when the user belongs to mars_group_1

# %%
# %sql
ALTER TABLE customer_pii_data_parquet
  ALTER COLUMN address SET MASK fn_col_mask USING COLUMNS (region,'West') ;

# %% [markdown]
# ### Test 3 -
#   - User is still part of mars_group_1 which restricts the user to see all the data as per the function definition
#   - The user is not allowed is see any DoB data based on the first alter table statement
#   - The user is only allowed to see address when region is West

# %%
# %sql
SELECT is_account_group_member('mars_group_1') as group_1, is_account_group_member('mars_group_2') as group_2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>group_1</th><th>group_2</th></tr></thead><tbody><tr><td>true</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
select * from customer_pii_data_parquet where region='West' limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>record_id</th><th>first_name</th><th>last_name</th><th>date_of_birth</th><th>age</th><th>gender</th><th>address</th><th>ssn</th><th>region</th></tr></thead><tbody><tr><td>32</td><td>Doe</td><td>Johnson</td><td>❌❌❌❌❌</td><td>33</td><td>M</td><td>456 Elm St</td><td>111-11-1111</td><td>West</td></tr><tr><td>18</td><td>Doe</td><td>Williams</td><td>❌❌❌❌❌</td><td>23</td><td>F</td><td>123 Main St</td><td>111-11-1111</td><td>West</td></tr><tr><td>16</td><td>Jane</td><td>Johnson</td><td>❌❌❌❌❌</td><td>38</td><td>F</td><td>789 Pine St</td><td>111-11-1111</td><td>West</td></tr><tr><td>25</td><td>Alice</td><td>Williams</td><td>❌❌❌❌❌</td><td>38</td><td>M</td><td>456 Elm St</td><td>222-22-2222</td><td>West</td></tr><tr><td>46</td><td>Jane</td><td>Smith</td><td>❌❌❌❌❌</td><td>23</td><td>F</td><td>789 Pine St</td><td>111-11-1111</td><td>West</td></tr><tr><td>18</td><td>Doe</td><td>Williams</td><td>❌❌❌❌❌</td><td>23</td><td>F</td><td>123 Main St</td><td>111-11-1111</td><td>West</td></tr><tr><td>46</td><td>Jane</td><td>Smith</td><td>❌❌❌❌❌</td><td>23</td><td>F</td><td>789 Pine St</td><td>111-11-1111</td><td>West</td></tr><tr><td>12</td><td>Alice</td><td>Williams</td><td>❌❌❌❌❌</td><td>43</td><td>F</td><td>456 Elm St</td><td>222-22-2222</td><td>West</td></tr><tr><td>14</td><td>Alice</td><td>Johnson</td><td>❌❌❌❌❌</td><td>33</td><td>F</td><td>101 Oak St</td><td>222-22-2222</td><td>West</td></tr><tr><td>16</td><td>Jane</td><td>Johnson</td><td>❌❌❌❌❌</td><td>38</td><td>F</td><td>789 Pine St</td><td>111-11-1111</td><td>West</td></tr></tbody></table></div>

# %%
# %sql
select * from customer_pii_data_parquet limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>record_id</th><th>first_name</th><th>last_name</th><th>date_of_birth</th><th>age</th><th>gender</th><th>address</th><th>ssn</th><th>region</th></tr></thead><tbody><tr><td>46</td><td>Jane</td><td>Smith</td><td>❌❌❌❌❌</td><td>23</td><td>F</td><td>789 Pine St</td><td>111-11-1111</td><td>West</td></tr><tr><td>47</td><td>Doe</td><td>Smith</td><td>❌❌❌❌❌</td><td>38</td><td>F</td><td>❌❌❌❌❌</td><td>111-11-1111</td><td>South</td></tr><tr><td>48</td><td>Jane</td><td>Smith</td><td>❌❌❌❌❌</td><td>38</td><td>F</td><td>❌❌❌❌❌</td><td>222-22-2222</td><td>South</td></tr><tr><td>49</td><td>Jane</td><td>Brown</td><td>❌❌❌❌❌</td><td>43</td><td>M</td><td>❌❌❌❌❌</td><td>333-33-3333</td><td>Northeast</td></tr><tr><td>37</td><td>John</td><td>Brown</td><td>❌❌❌❌❌</td><td>23</td><td>M</td><td>❌❌❌❌❌</td><td>333-33-3333</td><td>Midwest</td></tr><tr><td>38</td><td>John</td><td>Smith</td><td>❌❌❌❌❌</td><td>23</td><td>M</td><td>❌❌❌❌❌</td><td>111-11-1111</td><td>Northeast</td></tr><tr><td>39</td><td>John</td><td>Brown</td><td>❌❌❌❌❌</td><td>23</td><td>F</td><td>❌❌❌❌❌</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>18</td><td>Doe</td><td>Williams</td><td>❌❌❌❌❌</td><td>23</td><td>F</td><td>123 Main St</td><td>111-11-1111</td><td>West</td></tr><tr><td>19</td><td>John</td><td>Brown</td><td>❌❌❌❌❌</td><td>23</td><td>M</td><td>❌❌❌❌❌</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>20</td><td>John</td><td>Williams</td><td>❌❌❌❌❌</td><td>33</td><td>F</td><td>❌❌❌❌❌</td><td>333-33-3333</td><td>Southwest</td></tr></tbody></table></div>

# %% [markdown]
# ## Some more examples with new function definition

# %%
# %sql
ALTER TABLE customer_pii_data_delta ALTER COLUMN ssn DROP MASK;
ALTER TABLE customer_pii_data_parquet ALTER COLUMN date_of_birth DROP MASK;
ALTER TABLE customer_pii_data_parquet ALTER COLUMN address DROP MASK;

# %%
# %sql
drop function if exists fn_col_mask;
CREATE OR REPLACE FUNCTION fn_col_mask(column_1 STRING, column_2 STRING, column_value_2 STRING, column_3 STRING, column_value_3 STRING) 
  RETURN IF((is_account_group_member("mars_group_1") AND column_2 = column_value_2) OR
            (is_account_group_member("mars_group_2") AND column_3 = column_value_3),
            column_1, "❌❌❌❌❌"
  );

# %%
# %sql
ALTER TABLE customer_pii_data_delta
  ALTER COLUMN ssn SET MASK fn_col_mask using columns (gender,'',region,'any');

# %%
# %sql
ALTER TABLE customer_pii_data_parquet
  ALTER COLUMN date_of_birth SET MASK fn_col_mask using columns (region,'',gender,'');

# %%
# %sql
SELECT is_account_group_member('mars_group_1') as group_1, is_account_group_member('mars_group_2') as group_2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>group_1</th><th>group_2</th></tr></thead><tbody><tr><td>false</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
select * from customer_pii_data_delta limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>record_id</th><th>first_name</th><th>last_name</th><th>date_of_birth</th><th>age</th><th>gender</th><th>address</th><th>ssn</th><th>region</th></tr></thead><tbody><tr><td>18</td><td>Doe</td><td>Williams</td><td>2000-01-01</td><td>23</td><td>F</td><td>123 Main St</td><td>❌❌❌❌❌</td><td>West</td></tr><tr><td>19</td><td>John</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>M</td><td>456 Elm St</td><td>❌❌❌❌❌</td><td>Midwest</td></tr><tr><td>20</td><td>John</td><td>Williams</td><td>1990-01-01</td><td>33</td><td>F</td><td>789 Pine St</td><td>❌❌❌❌❌</td><td>Southwest</td></tr><tr><td>37</td><td>John</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>M</td><td>789 Pine St</td><td>❌❌❌❌❌</td><td>Midwest</td></tr><tr><td>38</td><td>John</td><td>Smith</td><td>2000-01-01</td><td>23</td><td>M</td><td>789 Pine St</td><td>❌❌❌❌❌</td><td>Northeast</td></tr><tr><td>39</td><td>John</td><td>Brown</td><td>2000-01-01</td><td>23</td><td>F</td><td>789 Pine St</td><td>❌❌❌❌❌</td><td>Midwest</td></tr><tr><td>34</td><td>Jane</td><td>Brown</td><td>1995-01-01</td><td>28</td><td>F</td><td>123 Main St</td><td>❌❌❌❌❌</td><td>South</td></tr><tr><td>35</td><td>Jane</td><td>Brown</td><td>1990-01-01</td><td>33</td><td>M</td><td>789 Pine St</td><td>❌❌❌❌❌</td><td>Northeast</td></tr><tr><td>36</td><td>Doe</td><td>Brown</td><td>1985-01-01</td><td>38</td><td>F</td><td>456 Elm St</td><td>❌❌❌❌❌</td><td>Northeast</td></tr><tr><td>9</td><td>Jane</td><td>Johnson</td><td>1980-01-01</td><td>43</td><td>F</td><td>456 Elm St</td><td>❌❌❌❌❌</td><td>South</td></tr></tbody></table></div>

# %%
# %sql
select * from customer_pii_data_parquet limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>record_id</th><th>first_name</th><th>last_name</th><th>date_of_birth</th><th>age</th><th>gender</th><th>address</th><th>ssn</th><th>region</th></tr></thead><tbody><tr><td>18</td><td>Doe</td><td>Williams</td><td>❌❌❌❌❌</td><td>23</td><td>F</td><td>123 Main St</td><td>111-11-1111</td><td>West</td></tr><tr><td>19</td><td>John</td><td>Brown</td><td>❌❌❌❌❌</td><td>23</td><td>M</td><td>456 Elm St</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>20</td><td>John</td><td>Williams</td><td>❌❌❌❌❌</td><td>33</td><td>F</td><td>789 Pine St</td><td>333-33-3333</td><td>Southwest</td></tr><tr><td>37</td><td>John</td><td>Brown</td><td>❌❌❌❌❌</td><td>23</td><td>M</td><td>789 Pine St</td><td>333-33-3333</td><td>Midwest</td></tr><tr><td>38</td><td>John</td><td>Smith</td><td>❌❌❌❌❌</td><td>23</td><td>M</td><td>789 Pine St</td><td>111-11-1111</td><td>Northeast</td></tr><tr><td>39</td><td>John</td><td>Brown</td><td>❌❌❌❌❌</td><td>23</td><td>F</td><td>789 Pine St</td><td>222-22-2222</td><td>Midwest</td></tr><tr><td>34</td><td>Jane</td><td>Brown</td><td>❌❌❌❌❌</td><td>28</td><td>F</td><td>123 Main St</td><td>222-22-2222</td><td>South</td></tr><tr><td>35</td><td>Jane</td><td>Brown</td><td>❌❌❌❌❌</td><td>33</td><td>M</td><td>789 Pine St</td><td>555-55-5555</td><td>Northeast</td></tr><tr><td>36</td><td>Doe</td><td>Brown</td><td>❌❌❌❌❌</td><td>38</td><td>F</td><td>456 Elm St</td><td>333-33-3333</td><td>Northeast</td></tr><tr><td>9</td><td>Jane</td><td>Johnson</td><td>❌❌❌❌❌</td><td>43</td><td>F</td><td>456 Elm St</td><td>555-55-5555</td><td>South</td></tr></tbody></table></div>

# %% [markdown]
# # Appendix

# %%
# %sql
drop function if exists fn_row_filter;
CREATE OR REPLACE FUNCTION fn_row_filter(column_value STRING)
  RETURN IF (is_account_group_member("ANALYST_SPAIN"), TRUE,  column_value="West"
  and EXISTS(SELECT 1 FROM valid_users v
    WHERE v.username = CURRENT_USER()));

# %%
# %sql
ALTER TABLE customer_pii_data_delta
  SET ROW FILTER fn_row_filter ON (region);

# %%
# %sql
ALTER TABLE customer_pii_data_parquet DROP ROW FILTER;

# %% [markdown]
# # UC Group membership lookup

# %%
# %sql
SHOW GROUPS WITH USER `dipankar.kushari@databricks.com`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>directGroup</th></tr></thead><tbody><tr><td>admins</td><td>true</td></tr><tr><td>dkushari-test-group-2025</td><td>true</td></tr><tr><td>team.fieldeng-all</td><td>true</td></tr><tr><td>ANALYST_USA</td><td>true</td></tr><tr><td>test_dk_group</td><td>true</td></tr><tr><td>mars_group_1</td><td>true</td></tr><tr><td>meijer_mkt_group</td><td>false</td></tr><tr><td>mygroup</td><td>true</td></tr><tr><td>all_analysts</td><td>false</td></tr><tr><td>meijer_sales_group</td><td>false</td></tr><tr><td>uday-dipankar</td><td>true</td></tr><tr><td>marketing_group</td><td>true</td></tr><tr><td>BimboPII_1</td><td>false</td></tr><tr><td>account users</td><td>true</td></tr><tr><td>federate_basic_group</td><td>true</td></tr><tr><td>mars_test_group</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
DROP TABLE IF EXISTS dkushari_uc.fgac.valid_users;

CREATE TABLE dkushari_uc.fgac.valid_users(username string);
INSERT INTO dkushari_uc.fgac.valid_users
VALUES
  ('dipankar.kushari@databricks.com'),
  ('sreeramreddy.thoom@databricks.com');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
SELECT is_account_group_member('ANALYST_SPAIN')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>is_account_group_member(ANALYST_SPAIN)</th></tr></thead><tbody><tr><td>false</td></tr></tbody></table></div>

# %%
# %sql
drop table if exists valid_accounts;
CREATE TABLE if not exists valid_accounts(account string);
INSERT INTO valid_accounts
VALUES
  ('ANALYST_ES'),
  ('ANALYST_SPAIN');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>
